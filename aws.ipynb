# %%
#creating bucket
import boto3

s3=boto3.client('s3')
s3.create_bucket(Bucket='my-bucket-today')
# Out:
# {'ResponseMetadata': {'RequestId': 'F922CBE79DB0524F',
#   'HostId': 'RQRyqXTH1xtLU+tbeP2gAAWiKYiglU9hCr7pZvXovGdsrzHr5Zq1JU6CZWowGDdSjRKM5XA06i0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'RQRyqXTH1xtLU+tbeP2gAAWiKYiglU9hCr7pZvXovGdsrzHr5Zq1JU6CZWowGDdSjRKM5XA06i0=',
#    'x-amz-request-id': 'F922CBE79DB0524F',
#    'date': 'Wed, 20 Nov 2019 18:35:30 GMT',
#    'location': '/my-bucket-today',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': '/my-bucket-today'}

# %%
# Setting bucket policy
import boto3
import json

# Create an S3 client
s3 = boto3.client('s3')

bucket_name = 'my-bucket-today'

# Create the bucket policy
bucket_policy = {
    'Version': '2012-10-17',
    'Statement': [{
        'Sid': 'AddPerm',
        'Effect': 'Allow',
        'Principal': '*',
        'Action': ['s3:GetObject'],
        'Resource': "arn:aws:s3:::%s/*" % bucket_name
    }]
}

# Convert the policy to a JSON string
bucket_policy = json.dumps(bucket_policy)

# Set the new policy on the given bucket
s3.put_bucket_policy(Bucket=bucket_name, Policy=bucket_policy)
# Out:
# {'ResponseMetadata': {'RequestId': '30A5A1D0C76B68BB',
#   'HostId': 'g237+XmOPFkzYdRU0ueEqVO+uXnldo6wCKT3WwlPZCL9Rayq0V6Wj1Y6/wcDb456bL/27KOPffw=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'g237+XmOPFkzYdRU0ueEqVO+uXnldo6wCKT3WwlPZCL9Rayq0V6Wj1Y6/wcDb456bL/27KOPffw=',
#    'x-amz-request-id': '30A5A1D0C76B68BB',
#    'date': 'Wed, 20 Nov 2019 18:39:13 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
#Uploading file to s3

import boto3

# Create an S3 client
S3 = boto3.client('s3')


# Uploads the given file using a managed uploader, which will split up large
# files automatically and upload parts in parallel.
S3.upload_file("C:/Users/Rajesh/Desktop/aws/testfile.txt", "my-bucket-today", "testdata.txt")

# %%
import logging
import boto3
from botocore.exceptions import ClientError


def delete_object(bucket_name, object_name):
    """Delete an object from an S3 bucket

    :param bucket_name: string
    :param object_name: string
    :return: True if the referenced object was deleted, otherwise False
    """

    # Delete the object
    s3 = boto3.client('s3')
    try:
        s3.delete_object(Bucket=bucket_name, Key=object_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True


def main():

    # Assign these values before running the program
    test_bucket_name = 'my-bucket-today'
    test_object_name = 'testdata.txt'

   
    # Delete the object
    if delete_object(test_bucket_name, test_object_name):
        logging.info(f'{test_object_name} was deleted from {test_bucket_name}')


if __name__ == '__main__':
    main()

# %%
# Get object from s3


import logging
import boto3
from botocore.exceptions import ClientError


def get_object(bucket_name, object_name):
    """Retrieve an object from an Amazon S3 bucket

    :param bucket_name: string
    :param object_name: string
    :return: botocore.response.StreamingBody object. If error, return None.
    """

    # Retrieve the object
    s3 = boto3.client('s3')
    try:
        response = s3.get_object(Bucket=bucket_name, Key=object_name)
    except ClientError as e:
        # AllAccessDisabled error == bucket or object not found
        logging.error(e)
        return None
    # Return an open StreamingBody object
    return response['Body']


def main():
    """Exercise get_object()"""

    # Assign these values before running the program
    test_bucket_name = 'my-bucket-today'
    test_object_name = 'testdata.txt'

    
    logging.basicConfig(filename="newfile.log", 
                    format='%(asctime)s %(message)s', 
                    filemode='w')
    
    #Creating an object 
    logger=logging.getLogger()

    # Retrieve the object
    stream = get_object(test_bucket_name, test_object_name)
    if stream is not None:
        # Read first chunk of the object's contents into memory as bytes
        data = stream.read(amt=1024)

        # Output object's beginning characters
        logger.info(data)
        
        


if __name__ == '__main__':
    main()
# Out:
# DEBUG:botocore.hooks:Event choose-service-name: calling handler <function handle_service_name_alias at 0x00000049901CC620>
# DEBUG:botocore.hooks:Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x00000049901BB158>
# DEBUG:botocore.hooks:Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x0000004990253B70>
# DEBUG:botocore.hooks:Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x00000049901B7EA0>
# DEBUG:botocore.args:The s3 config key is not a dictionary type, ignoring its value of: None
# DEBUG:botocore.endpoint:Setting s3 timeout as (60, 60)
# DEBUG:botocore.client:Registering retry handlers for service: s3
# DEBUG:botocore.client:Defaulting to S3 virtual host style addressing with path style addressing fallback.
# DEBUG:botocore.hooks:Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x00000049901E6F28>
# ...
